# %% [markdown]
# # Ejercicios de Asesoria (Montecarlo)

# %% [markdown]
# |                |   |
# :----------------|---|
# | **Nombre**     |  Jorge Oviedo Magaña |
# | **Fecha**      | 09/03/2026 |
# | **Expediente** |  757048 |

# %% [markdown]
# 1.- Dos equipos juegan una serie de juegos (4 de 7, el que gane 4 juegos gana). Cada equipo tiene un 50% de probabilidad de ganar cada juego (no empates). ¿Cuál es la probabilidad de que la serie se vaya a 7 juegos? (5/16)

# %%
import numpy as np

N = 1_000_000
series_de_7 = 0

for i in range(N):
    wins_a = 0
    wins_b = 0

    while wins_a < 4 and wins_b < 4:
        if np.random.rand() < 0.5:
            wins_a += 1
        else:
            wins_b += 1

    if wins_a + wins_b == 7:
        series_de_7 += 1

prob = series_de_7 / N

print("Probabilidad", prob)
# Out:
# Probabilidad 0.313248

# %% [markdown]
# 2.- Una en mil personas tienen una enfermedad H, y la prueba de la enfermedad sale correcta 98% de las veces cuando la persona está enferma. Por otro lado, si la persona no está enferma la prueba tiene un error del 1%. Si alguien se hace una prueba y sale positiva, ¿cuál es la probabilidad de que tengan la enfermedad? (98/1097)

# %%
n = 1000000
positivos = 0 #inician en 0
enfermos_y_positivos = 0

for i in range(n):

    enfermo = np.random.rand() < 0.001
    
    if enfermo:
        positivo = np.random.rand() < 0.98
    else:
        positivo = np.random.rand() < 0.01
    
    if positivo:
        positivos += 1
        if enfermo:
            enfermos_y_positivos += 1

prob = (enfermos_y_positivos/ positivos) * 100

print("Probabiblidad", prob, "%")
# Out:
# Probabiblidad 8.822191905411552 %

# %% [markdown]
# 3.- Tres amigos diferentes te dijeron que está lloviendo, y cada persona tiene 1/3 de probabilidad de mentir. Si el pronóstico del clima dijo que la probabilidad de lluvia era 25%, ¿cuál es la probabilidad de que sí esté lloviendo? (8/11)

# %%
n = 1000000
tres_si = 0
tres_si_y_llueve = 0

for i in range(n):
    esta_lloviendo = np.random.rand() < 0.25

    if esta_lloviendo:
        amigo1 = np.random.rand() < 2/3
        amigo2 = np.random.rand() < 2/3
        amigo3 = np.random.rand() < 2/3
    else: 
        amigo1 = np.random.rand() < 1/3
        amigo2 = np.random.rand() < 1/3
        amigo3 = np.random.rand() < 1/3

    if amigo1 and amigo2 and amigo3:
        tres_si += 1
        if esta_lloviendo:
            tres_si_y_llueve += 1


prob = tres_si_y_llueve/ tres_si

print("Probabilidad", prob)
# Out:
# Probabilidad 0.7277767964042474
