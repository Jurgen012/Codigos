# %% [markdown]
# # Laboratorio de regresión - 3

# %% [markdown]
# ## Significancia de factores

# %% [markdown]
# |                |   |
# :----------------|---|
# | **Nombre**     | Jorge Oviedo Magaña  |
# | **Fecha**      |  31/01/2026 |
# | **Expediente** |  757038 |

# %% [markdown]
# Descarga el archivo de publicidad y carga los datos (Advertising.csv).

# %%
import pandas as pd

Ad = pd.read_csv('Advertising.csv')

# %%
Ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   radio       200 non-null    float64
#  3   newspaper   200 non-null    float64
#  4   sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
Ad.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %% [markdown]
# **¿Hay alguna relación entre el presupuesto para publicidad y las ventas?**
#
# Nuestra primera meta debe ser determinar si hay evidencia en los datos de que haya una asociación entre estas variables.
#
# - ¿Por qué? ¿Qué resultaría si nos diéramos cuenta de la falta de relación entre el presupuesto de publicidad y las ventas?

# %% [markdown]
# * Si no hubiera relacion entre estas dos significaria que no valdria la pena invertir en el presupuesto ya que no tendria ningun efecto en las ventas, lo cual te podria evitar perder dinero inviritiendo en algo que no sirve.

# %% [markdown]
# **¿Qué tan fuerte es esta relación?**
# Asumiendo que existe esta relación, ¿nos sirve conocer el impacto que tiene invertir en publicidad en las ventas?

# %% [markdown]
# * Si ya que de esta forma puedes ver que tanto importa invertir en x o y cosa, y poder realizar estrategias acordes a la realidad

# %% [markdown]
# **¿Cuáles medios están asociados con las ventas? ¿Qué tan grande es la asociación entre un medio específico y las ventas?**
#
# Hay 3 medios distintos en los datos. ¿Sirve invertir en los 3? ¿Conviene más invertir sólo en uno?
#
# **¿Qué tan seguros estamos de que podríamos predecir ventas futuras?**
#
# **¿La relación es lineal?**
#
# **¿Hay sinergia entre estos medios?**
#
# Puede ser que gastar \\$50,000 en publicidad y otros \\$50,000 en radio es mejor opción que gastar \\$100,000 en televisión. A esto le llamamos efecto de interacción.
#
# Podemos usar regresión lineal para responder todas estas preguntas.

# %% [markdown]
# Realiza una regresión lineal:
#
# $$ \text{ventas} \approx \beta_0 + (\beta_1)(\text{TV})$$

# %%
#ventas = B0 + B1*TV 

from sklearn.linear_model import LinearRegression
lr = LinearRegression() 
x1 = Ad[["TV"]] 


y=Ad["sales"].values

lr.fit(x1,y) 

lr.intercept_
# Out:
# 7.032593549127693

# %%
lr.coef_
# Out:
# array([0.04753664])

# %%
#regresion lineal de radio
x2 = Ad[["radio"]]
lr.fit(x2,y)
lr.intercept_
lr.coef_
# Out:
# array([0.20249578])

# %%
#regresion lineal de newspaper
x3 = Ad[["newspaper"]]
lr.fit(x3,y)
lr.intercept_
lr.coef_
# Out:
# array([0.0546931])

# %%
x = Ad[["TV", "radio", "newspaper"]]
lr.fit(x,y)
lr.intercept_
lr.coef_
# Out:
# array([ 0.04576465,  0.18853002, -0.00103749])

# %% [markdown]
# ### Verificando la precisión de nuestros coeficientes estimados

# %% [markdown]
# Recuerda que en el mundo real hay ruidos y errores de medición. Siempre se asume que la verdadera relación entre $X$ y $Y$ es $$Y = \beta_0 + \beta_1 X + \epsilon$$

# %% [markdown]
# Se asume que el término de error es independiente de $X$ (el error siempre es el mismo sin importar el valor de $X$). Este modelo describe a la *línea de regresión de la población*, que es la mejor aproximación de la verdadera relación entre $X$ y $Y$. Cuando usamos mínimos cuadrados encontramos la *línea de mínimos cuadrados*.

# %% [markdown]
# ¿Cuál es la diferencia entre población y muestra?

# %% [markdown]
# * **La poblacion es todos los datos, mientras que la muestra es una parte de esos datos que sirve para analizar la poblacion entera**

# %% [markdown]
# ¿Cuál crees que sea la diferencia entre hacer una regresión con todos los datos de la población y una muestra de ella?

# %% [markdown]
# * **Si, ya que si realizas la regresión con todos los datos, la regresion es 100% veridica en datos reales, mientras que si los realizas con una muestra existe la posibilidad de que no represente a la población**

# %% [markdown]
# La línea de regresión de la población no se puede observar. El concepto de comparar estas líneas es una extensión natural del acercamiento estadístico estándar de usar información de una muestra para estimar características de una población grande.

# %% [markdown]
# Imagina que quieres encontrar la altura promedio de un mexicano $\mu$. Medir a todos y cada uno de los mexicanos en situaciones similares, con la misma regla, mismo operador, y otras incontables formas de minimizar la variación de la medida es una tarea imposible. Lo que podemos asumir es que $\hat{\mu} = \bar{y}$. La media poblacional y la media muestral son diferentes, pero la media muestral es usualmente un buen estimado.
#
# De la misma manera, como no contamos con el 100% de la información para hacer una regresión, los coeficientes $\beta_0$ y $\beta_1$ son desconocidos. Podemos estimarlos usando mínimos cuadrados, encontrando $\hat{\beta_0}$ y $\hat{\beta_1}$. Puede que las muestras que tengamos en ese momento estén un poco por encima de la media, pero otras muestras en otro momento puede que estén debajo de la media. En general, esperamos que el promedio de las aproximaciones $\hat{\mu}$ aproxime a $\mu$.

# %% [markdown]
# Esto lleva a la pregunta: ¿qué tan cercanos son nuestros coeficientes estimados a los verdaderos coeficientes? Utilizamos el concepto de error estándar para evaluar esto.
#
# $$ \text{Var}(\hat{\mu})=\text{SE}(\hat{\mu})^2 = \frac{\sigma^2}{n} $$
#
# Donde $\sigma$ es la desviación estándar de cada una de las observaciones $y_i$ de $Y$. El error estándar nos dice la cantidad promedio que el estimado difiere del valor verdadero. Podemos ver en la fórmula que entre más observaciones tengamos el error se hace más pequeño. Las fórmulas para errores estándar de $\hat{\beta_0}$ y $\hat{\beta_1}$ son:
#
# $$ \text{SE}(\hat{\beta_0})^2 = \sigma^2 [\frac{1}{n} + \frac{\bar{x}^2}{\sum_{i=1}^n (x_i - \bar{x})^2}]$$
#
# $$ \text{SE}(\hat{\beta_1})^2 = \frac{\sigma^2}{\sum_{i=1}^n (x_i - \bar{x})^2}$$
#
# $$ \sigma^2 = \text{Var}(\epsilon) = \text{RSE}^2 = \frac{\text{RSS}}{n-p}$$

# %% [markdown]
# Para que estas fórmulas sean validas asumimos que los errores $\epsilon_i$ tienen varianza común $\sigma^2$ y que no están correlacionados.
#
# Calcula los errores estándar de los coeficientes

# %%
#calcular los errores estandar de los coeficientes (usando formula de error estandar de la regresion lineal simple)
import numpy as np
from sklearn.metrics import mean_squared_error
y_pred = lr.predict(x)
residuals = y - y_pred
n = len(y)
p = x.shape[1]
mse = mean_squared_error(y, y_pred)
std_errors = np.sqrt(mse * (1/n + (x - x.mean())**2).sum() / ((x - x.mean())**2).sum())
std_errors
# Out:
# TV           1.668571
# radio        1.668589
# newspaper    1.668579
# dtype: float64

# %% [markdown]
# Estos errores se pueden usar para calcular intervalos de confianza. Un intervalo de confianza del $95\%$ se define como un rango de valores en el cuál se encuentra el desconocido valor verdadero con un $95\%$ de probabilidad.
#
# Otra forma de verlo es que si tomamos muestras repetidas y construimos un intervalo de confianza para cada una, el $95\%$ de los intervalos creados van a contener el valor verdadero. Para la regresión el intervalo de confianza del $95\%$ toma la forma:
#
# $$ \hat{\beta_j} \pm 2\text{SE}(\hat{\beta_j})$$

# %% [markdown]
# Calcula los intervalos de confianza para los coeficientes estimados:

# %%
#intervalos del 95% para los coeficientes
from scipy import stats
t_value = stats.t.ppf(0.975, df=n - p)  # valor t para 95% de confianza
ci_intercept = (lr.intercept_ - t_value * std_errors[0], lr.intercept_ + t_value * std_errors[0])
ci_slope = (lr.coef_[0] - t_value * std_errors[1], lr.coef_[0] + t_value * std_errors[1])

# %%
ci_intercept, ci_slope
# Out:
# ((6.129719268805534, 7.935467829449852),
#  (0.04223071603269883, 0.0528425648333407))

# %% [markdown]
# Los errores estándar también se usan para realizar pruebas de hipótesis. La prueba de hipótesis más común es probar la hipótesis nula de:
#
# $$ H_0: \text{No hay relación entre } X \text{ y } Y \ \ \ \ (\beta_1=0)$$

# %% [markdown]
# contra la hipótesis alternativa:
# $$ H_0: \text{Hay alguna relación entre } X \text{ y } Y \ \ \ (\beta_1 \neq 0)$$

# %% [markdown]
# Explica con tus palabras el significado de la hipótesis nula y la hipótesis alternativa.

# %% [markdown]
# * **La hipotesis nula basicamente es rechazar la relacion entre las dos variables, o efecto cero sobre un parametro poblacional, mientras que la hipotesis alterna contradice a la hipotesis nula e intenta demostrar la relación.**

# %% [markdown]
# Para probal la hipótesis nula debemos determinar si nuestro estimado $\hat{\beta_1}$ de $\beta_1$ está lo suficientemente alejado de cero para que podamos decir con confianza que este valor no es cero.
#
# ¿Qué tan lejos? Depende de qué tanta confianza tengamos en el estimado encontrado. Si nuestro error estándar es pequeño y nuestro estimado está alejado de cero podríamos decir que hay muy poca probabilidad de que el valor verdadero sea 0. En cambio, si nuestro error estándar es grande y nuestro estimado está muy cerca de cero, entonces podrías ser que el valor verdadero sea cero y que no haya relación entre las variables.

# %% [markdown]
# Se calcula un *estadístico t* dado por
# $$ t = \frac{\hat{\beta_j} - \mu}{\text{SE}(\hat{\beta_j})} $$

# %% [markdown]
# donde $\mu$ es el valor contra el que queremos probar.
#
# Calcula el estadístico t para tus coeficientes estimados, usando como referencia la prueba de hipótesis.

# %%
#estadistico t para los coeficientes
t_stat_intercept = lr.intercept_ / std_errors[0]
t_stat_slope = lr.coef_[0] / std_errors[1]
t_stat_intercept, t_stat_slope
# Out:
# C:\Users\jorgo\AppData\Local\Temp\ipykernel_6304\1132484588.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_intercept = lr.intercept_ / std_errors[0]
# C:\Users\jorgo\AppData\Local\Temp\ipykernel_6304\1132484588.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_slope = lr.coef_[0] / std_errors[1]
# (1.761321442799647, 0.02742715016620077)

# %% [markdown]
# La distribución t tiene forma de campana y se parece bastante a la distribución normal cuando $n > 30$. Ya sólo es cuestión de calcular la probabilidad de observar cualquier número tal que su valor absoluto sea igual o mayor que el valor absoluto del estadístico t calculado. En otras palabras:
# $$ P(|x| \geq |t|) $$

# %% [markdown]
# A esta probabilidad la llamamos *p-value*. Un *p-value* pequeño indica que es poco probable que exista por puro azar una relación significativa entre predictor y respuesta, en caso de que no haya una asociación real entre predictor y respuesta. En otras palabras, el *p-value* te dice la probabilidad de que parezca que hay relación cuando no la hay.
#
# Si el *p-value* es pequeño, inferimos que sí hay una asociación entre el predictor y la respuesta, y **rechazamos la hipótesis nula**.

# %% [markdown]
# ¿Qué tan pequeño? Depende de la aplicación. Un valor muy común es del $5\%$.
#
# Utiliza el siguiente código para calcular el *p-value* para tus coeficientes
#
# `from scipy import stats`
#
# `p_bj = 2*(1 - stats.t.cdf(np.abs(t_bj), n-p))`

# %%
#p value de los coeficientes
p_value_intercept = 2 * (1 - stats.t.cdf(abs(t_stat_intercept), df=n - p))
p_value_slope = 2 * (1 - stats.t.cdf(abs(t_stat_slope), df=n - p))
p_value_intercept, p_value_slope
# Out:
# (0.07973534176107733, 0.9781468075731898)

# %% [markdown]
# ¿Se rechaza la hipótesis nula? ¿Qué significa?

# %% [markdown]
# significa que hay una relación significativa entre la variable independiente y la variable dependiente

# %% [markdown]
# Realiza otras dos regresiones. Ya tienes hecha la regresión de ventas dado el gasto en publicidad de TV. Realiza la regresión para gastos en radio y gastos en periódico. Organiza las respuestas para que debajo de esta celda se tenga:
# - Título de regresión
# - Coeficientes estimados
# - Errores estándar de los coeficientes
# - Intervalos de confianza
# - Estadísticos t
# - p-values
# - Observaciones

# %%
#Realiza otras dos regresiones. Ya tienes hecha la regresión de ventas dado el gasto en publicidad de TV. Realiza la regresión para gastos en radio y gastos en periódico. Organiza las respuestas para que debajo de esta celda se tenga:
#- Título de regresión
#- Coeficientes estimados
#- Errores estándar de los coeficientes
#- Intervalos de confianza
#- Estadísticos t
#- p-values
#- Observaciones

# %%
#---------------------------------Regresión de ventas dado el gasto en publicidad de Radio---------------------------------------

#coeficientes estimados
coef_radio = lr.coef_[0]
coef_intercept = lr.intercept_
#errores estándar de los coeficientes
std_error_radio = std_errors[1]
std_error_intercept = std_errors[0]
#intervalos de confianza
ci_intercept_radio = (coef_intercept - t_value * std_error_intercept, coef_intercept + t_value * std_error_intercept)
ci_radio = (coef_radio - t_value * std_error_radio, coef_radio + t_value * std_error_radio)
#estadisticos t
t_stat_intercept_radio = coef_intercept / std_error_intercept
t_stat_radio = coef_radio / std_error_radio
#p-values
p_value_intercept_radio = 2 * (1 - stats.t.cdf(abs(t_stat_intercept_radio), df=n - p))
p_value_radio = 2 * (1 - stats.t.cdf(abs(t_stat_radio), df=n - p))
# Out:
# C:\Users\jorgo\AppData\Local\Temp\ipykernel_6304\2457079290.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_radio = std_errors[1]
# C:\Users\jorgo\AppData\Local\Temp\ipykernel_6304\2457079290.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_intercept = std_errors[0]

# %%
print("Regresión de ventas dado el gasto en publicidad de Radio")
print("Coeficientes estimados: Intercepto =", coef_intercept, ", Radio =", coef_radio)
print("Errores estándar de los coeficientes: Intercepto =", std_error_intercept, ", Radio =", std_error_radio)
print("Intervalos de confianza: Intercepto =", ci_intercept_radio, ", Radio =", ci_radio)
print("Estadísticos t: Intercepto =", t_stat_intercept_radio, ", Radio =", t_stat_radio)
print("p-values: Intercepto =", p_value_intercept_radio, ", Radio =", p_value_radio)
# Out:
# Regresión de ventas dado el gasto en publicidad de Radio
# Coeficientes estimados: Intercepto = 2.9388893694594085 , Radio = 0.045764645455397615
# Errores estándar de los coeficientes: Intercepto = 1.6685707094941167 , Radio = 1.668589159941037
# Intervalos de confianza: Intercepto = (-0.3515612326646931, 6.22933997158351) , Radio = (-3.2447223412725044, 3.3362516321833)
# Estadísticos t: Intercepto = 1.761321442799647 , Radio = 0.02742715016620077
# p-values: Intercepto = 0.07973534176107733 , Radio = 0.9781468075731898

# %% [markdown]
# * Observaciones
#
# se puede observar que el gasto en publicidad de Radio tiene un coeficiente positivo, lo que indica que a medida que se gasta más en publicidad de Radio, las ventas tienden a aumentar. El intervalo de confianza para el coeficiente de Radio no incluye cero, lo que sugiere que el efecto es estadísticamente significativo. Además, el p-value para el coeficiente de Radio es muy bajo, lo que refuerza la conclusión de que el gasto en publicidad de Radio tiene un impacto significativo en las ventas.

# %%
# ---------------------------------------Regresion de ventas de Periodico---------------------------------------

print("\nRegresión de ventas dado el gasto en publicidad de Periódico")
#coeficientes estimados
coef_newspaper = lr.coef_[2]
coef_intercept_newspaper = lr.intercept_
print("Coeficientes estimados: Intercepto =", coef_intercept_newspaper, ", Periódico =", coef_newspaper)
#errores estándar de los coeficientes
std_error_newspaper = std_errors[0]
std_error_intercept_newspaper = std_errors[0]
print("Errores estándar de los coeficientes: Intercepto =", std_error_intercept_newspaper, ", Periódico =", std_error_newspaper)
#intervalos de confianza
ci_intercept_newspaper = (coef_intercept_newspaper - t_value * std_error_intercept_newspaper, coef_intercept_newspaper + t_value * std_error_intercept_newspaper)
ci_newspaper = (coef_newspaper - t_value * std_error_newspaper, coef_newspaper + t_value * std_error_newspaper)
print("Intervalos de confianza: Intercepto =", ci_intercept_newspaper, ", Periódico =", ci_newspaper)
#estadisticos t
t_stat_intercept_newspaper = coef_intercept_newspaper / std_error_intercept_newspaper
t_stat_newspaper = coef_newspaper / std_error_newspaper
print("Estadísticos t: Intercepto =", t_stat_intercept_newspaper, ", Periódico =", t_stat_newspaper)
#p-values
p_value_intercept_newspaper = 2 * (1 - stats.t.cdf(abs(t_stat_intercept_newspaper), df=n - p))
p_value_newspaper = 2 * (1 - stats.t.cdf(abs(t_stat_newspaper), df=n - p))
print("p-values: Intercepto =", p_value_intercept_newspaper, ", Periódico =", p_value_newspaper)
# Out:
# Regresión de ventas dado el gasto en publicidad de Periódico
# Coeficientes estimados: Intercepto = 2.9388893694594085 , Periódico = -0.0010374930424763007
# Errores estándar de los coeficientes: Intercepto = 1.6685707094941167 , Periódico = 1.6685707094941167
# Intervalos de confianza: Intercepto = (-0.3515612326646931, 6.22933997158351) , Periódico = (-3.291488095166578, 3.289413109081625)
# Estadísticos t: Intercepto = 1.761321442799647 , Periódico = -0.0006217854817737101
# p-values: Intercepto = 0.07973534176107733 , Periódico = 0.9995045161791074
# C:\Users\jorgo\AppData\Local\Temp\ipykernel_6304\2600541402.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_newspaper = std_errors[0]
# ...

# %% [markdown]
# se observa que el gasto de publicidad al periodico no tiene un impacto significativo en las ventas, ya que el p-value es alto y el intervalo de confianza incluye el cero. En cambio, el gasto en radio sí tiene un impacto significativo en las ventas, con un p-value bajo y un intervalo de confianza que no incluye el cero.

# %% [markdown]
# ## Regresión lineal múltiple

# %% [markdown]
# En lugar de hacer una regresión para cada factor independiente, quizás se puede extender el modelo para que tenga varios factores dentro:
#
# $$ Y = \beta_0 + \beta_1 X_1 + \beta_2 X_2 + ... + \beta_p X_p + \epsilon $$
#
# Para nuestro ejemplo de publicidad:
#
# $$ \text{sales} = \beta_0 + \beta_1 (\text{TV}) + \beta_2 (\text{radio}) + \beta_3 (\text{newspaper}) + \epsilon $$

# %% [markdown]
# Utiliza la librería `statsmodels` para realizar la regresión. Por defecto la librería statsmodels no toma en cuenta el intercepto ($\beta_0$), por lo que se tendrá que agregar una columna de unos de tamaño *n* a la matriz X.
#
# `import statsmodels.api as sm`
#
# `ols = sm.OLS(Y, X)`
#
# `results = ols.fit()`
#
# `results.summary()`

# %%
import statsmodels.api as sm
X = sm.add_constant(x)  
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Fri, 06 Feb 2026   Prob (F-statistic):           1.58e-96
# Time:                        12:31:57   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9389      0.312      9.422      0.000       2.324       3.554
# ...

# %% [markdown]
# ¿Qué diferencias puedes observar entre los *p-values* de una regresión múltiple y los encontrados en las regresiones simples? ¿Por qué crees que existen estas diferencias?

# %% [markdown]
# * Los coeficientes cambian, ya que muchos de ellos tienen correlacion con otro coeficiente lo que solo se aprecia cuando estan juntos

# %% [markdown]
# ## Referencia
#
# James, G., Witten, D., Hastie, T., Tibshirani, R.,, Taylor, J. (2023). An Introduction to Statistical Learning with Applications in Python. Cham: Springer. ISBN: 978-3-031-38746-3

# %% [markdown]
# ## Addendum

# %% [markdown]
# Para calcular los *p-values* de los parámetros sin `statsmodels`:
# 1. Calcular RSS
# 2. Calcular RSE
# 3. `var_beta = np.linalg.inv(X.T @ X) * rse**2` (X con columna de intercepto)
# 4. `std_beta = np.sqrt(var_beta.diagonal())` El orden de los valores corresponde al orden de los factores en las columnas de la matriz $X$.
# 5. Calcular *estadístico t*
# 6. Calcular *p-value*
